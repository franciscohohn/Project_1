# %%
#dependencies
import pandas as pd
import numpy as np

# files to Load
cpd_crime2018_load = "Crimes_-_2018.csv"
cpd_crime2017_load = "Crimes_-_2017.csv"
cpd_crime2016_load = "Crimes_-_2016.csv"
cpd_crime2015_load = "Crimes_-_2015.csv"
cpd_crime2014_load = "Crimes_-_2014.csv"

# read CPD crime data and store
cpdcrime2018_data = pd.read_csv(cpd_crime2018_load)
cpdcrime2017_data = pd.read_csv(cpd_crime2017_load)
cpdcrime2016_data = pd.read_csv(cpd_crime2016_load)
cpdcrime2015_data = pd.read_csv(cpd_crime2015_load)
cpdcrime2014_data = pd.read_csv(cpd_crime2014_load)

# %%
cpdcrime2018_data = cpdcrime2018_data[['Date', 'Primary Type', 'Year']]
cpdcrime2018_data = cpdcrime2018_data.dropna(how='any')

cpdcrime2017_data = cpdcrime2017_data[['Date', 'Primary Type', 'Year']]
cpdcrime2017_data = cpdcrime2017_data.dropna(how='any')

cpdcrime2016_data = cpdcrime2016_data[['Date', 'Primary Type', 'Year']]
cpdcrime2016_data = cpdcrime2016_data.dropna(how='any')

cpdcrime2015_data = cpdcrime2015_data[['Date', 'Primary Type', 'Year']]
cpdcrime2015_data = cpdcrime2015_data.dropna(how='any')

cpdcrime2014_data = cpdcrime2014_data[['Date', 'Primary Type', 'Year']]
cpdcrime2014_data = cpdcrime2014_data.dropna(how='any')

# %%
#use to check outputs
#cpdcrime2018_data.head()
#cpdcrime2017_data.head()
#cpdcrime2016_data.head()
#cpdcrime2015_data.head()
#cpdcrime2014_data.head()

# %%
cpdcrime2018_bytype = cpdcrime2018_data.sort_values(by=["Primary Type", "Date"])
cpdcrime2017_bytype = cpdcrime2017_data.sort_values(by=["Primary Type", "Date"])
cpdcrime2016_bytype = cpdcrime2016_data.sort_values(by=["Primary Type", "Date"])
cpdcrime2015_bytype = cpdcrime2015_data.sort_values(by=["Primary Type", "Date"])
cpdcrime2014_bytype = cpdcrime2014_data.sort_values(by=["Primary Type", "Date"])

# %%
#use to check output
cpdcrime2018_bytype
#cpdcrime2017_bytype
#cpdcrime2016_bytype
#cpdcrime2015_bytype
#cpdcrime2014_bytype
# Out:
#                           Date       Primary Type  Year
# 265869  01/03/2018 01:00:00 AM              ARSON  2018
# 264625  01/04/2018 04:24:00 AM              ARSON  2018
# 264183  01/04/2018 06:58:00 PM              ARSON  2018
# 261839  01/09/2018 10:07:00 PM              ARSON  2018
# 262266  01/09/2018 10:20:00 AM              ARSON  2018
# 259954  01/11/2018 06:10:00 PM              ARSON  2018
# 257792  01/13/2018 10:40:00 PM              ARSON  2018
# 259129  01/14/2018 10:24:00 AM              ARSON  2018
# 257653  01/16/2018 01:30:00 AM              ARSON  2018
# 256189  01/17/2018 05:35:00 PM              ARSON  2018
# 256507  01/18/2018 05:05:00 PM              ARSON  2018
# 255318  01/19/2018 08:50:00 AM              ARSON  2018
# 255758  01/20/2018 07:35:00 PM              ARSON  2018
# 254424  01/21/2018 03:22:00 AM              ARSON  2018
# 254692  01/21/2018 05:50:00 PM              ARSON  2018
# 255032  01/22/2018 12:24:00 AM              ARSON  2018
# 253304  01/23/2018 05:30:00 PM              ARSON  2018
# 127691  01/25/2018 10:00:00 PM              ARSON  2018
# 251050  01/26/2018 10:23:00 AM              ARSON  2018
# 249582  01/28/2018 01:35:00 AM              ARSON  2018
# 249568  01/28/2018 01:43:00 AM              ARSON  2018
# 249518  01/28/2018 05:38:00 AM              ARSON  2018
# 248434  01/30/2018 04:30:00 AM              ARSON  2018
# 248698  01/30/2018 06:00:00 AM              ARSON  2018
# 248114  01/30/2018 07:20:00 PM              ARSON  2018
# 3200    01/31/2018 05:11:00 AM              ARSON  2018
# 246860  02/02/2018 05:19:00 AM              ARSON  2018
# 245605  02/02/2018 08:04:00 PM              ARSON  2018
# 246175  02/02/2018 09:20:00 PM              ARSON  2018
# 246118  02/03/2018 09:57:00 AM              ARSON  2018
# ...                        ...                ...   ...
# 4775    12/30/2018 08:59:00 PM  WEAPONS VIOLATION  2018
# 4815    12/30/2018 09:00:00 PM  WEAPONS VIOLATION  2018
# 4768    12/30/2018 09:22:00 PM  WEAPONS VIOLATION  2018
# 4795    12/30/2018 09:35:00 PM  WEAPONS VIOLATION  2018
# 4920    12/30/2018 10:16:00 AM  WEAPONS VIOLATION  2018
# 5595    12/30/2018 11:10:00 AM  WEAPONS VIOLATION  2018
# 4761    12/30/2018 11:18:00 PM  WEAPONS VIOLATION  2018
# 4746    12/30/2018 11:45:00 PM  WEAPONS VIOLATION  2018
# 5653    12/30/2018 12:15:00 PM  WEAPONS VIOLATION  2018
# 4705    12/31/2018 01:15:00 AM  WEAPONS VIOLATION  2018
# 4394    12/31/2018 07:39:00 PM  WEAPONS VIOLATION  2018
# 4353    12/31/2018 08:51:00 PM  WEAPONS VIOLATION  2018
# 5171    12/31/2018 08:55:00 AM  WEAPONS VIOLATION  2018
# 3321    12/31/2018 09:00:00 PM  WEAPONS VIOLATION  2018
# 4870    12/31/2018 09:45:00 PM  WEAPONS VIOLATION  2018
# 4839    12/31/2018 09:46:00 PM  WEAPONS VIOLATION  2018
# 4327    12/31/2018 09:55:00 PM  WEAPONS VIOLATION  2018
# 4344    12/31/2018 09:58:00 PM  WEAPONS VIOLATION  2018
# 4869    12/31/2018 10:10:00 PM  WEAPONS VIOLATION  2018
# 4874    12/31/2018 10:12:00 PM  WEAPONS VIOLATION  2018
# 4867    12/31/2018 10:20:00 PM  WEAPONS VIOLATION  2018
# 4854    12/31/2018 10:45:00 PM  WEAPONS VIOLATION  2018
# 4326    12/31/2018 10:51:00 PM  WEAPONS VIOLATION  2018
# 4317    12/31/2018 11:08:00 PM  WEAPONS VIOLATION  2018
# 4847    12/31/2018 11:12:00 PM  WEAPONS VIOLATION  2018
# 4334    12/31/2018 11:26:00 PM  WEAPONS VIOLATION  2018
# 4286    12/31/2018 11:40:00 PM  WEAPONS VIOLATION  2018
# 4332    12/31/2018 11:43:00 PM  WEAPONS VIOLATION  2018
# 4715    12/31/2018 12:02:00 AM  WEAPONS VIOLATION  2018
# 4719    12/31/2018 12:08:00 AM  WEAPONS VIOLATION  2018
#
# [266174 rows x 3 columns]

# %%
cpdcrime2018_bytype.set_index(["Primary Type", "Date"]).count(level="Primary Type")
# Out:
#                                     Year
# Primary Type
# ARSON                                372
# ASSAULT                            20375
# BATTERY                            49779
# BURGLARY                           11732
# CONCEALED CARRY LICENSE VIOLATION    149
# CRIM SEXUAL ASSAULT                 1626
# CRIMINAL DAMAGE                    27804
# CRIMINAL TRESPASS                   6904
# DECEPTIVE PRACTICE                 18692
# GAMBLING                             201
# HOMICIDE                             586
# HUMAN TRAFFICKING                     14
# INTERFERENCE WITH PUBLIC OFFICER    1305
# INTIMIDATION                         168
# KIDNAPPING                           169
# LIQUOR LAW VIOLATION                 266
# MOTOR VEHICLE THEFT                 9988
# NARCOTICS                          12963
# NON-CRIMINAL                          37
# NON-CRIMINAL (SUBJECT SPECIFIED)       3
# OBSCENITY                             86
# OFFENSE INVOLVING CHILDREN          2230
# OTHER NARCOTIC VIOLATION               1
# OTHER OFFENSE                      17120
# PROSTITUTION                         718
# PUBLIC INDECENCY                      14
# PUBLIC PEACE VIOLATION              1369
# ROBBERY                             9683
# SEX OFFENSE                         1101
# STALKING                             203
# THEFT                              65068
# WEAPONS VIOLATION                   5448

# %%
concise_cpdcrime2018_bytype = pd.DataFrame({"City": city_names,
                           "Cloudiness": clouds,
                           "Country": country,
                           "Date": date,
                           "Humidity": humidity,
                           "Lat": lat,
                           "Lng": lng,
                           "Max Temp": max_temp,
                           "Wind Speed": wind_speed
                          })
# Out:
#   File "<ipython-input-11-c6e6938d3b45>", line 1
#     concise_cpdcrime2018_bytype = cpdcrime2018_bytype[cpdcrime2018_bytype['Primary Type'].isin(['ASSAULT', 'BATTERY'])
#                                                                                                                       ^
# SyntaxError: unexpected EOF while parsing

# %%
concise_cpdcrime2018_bytype
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-ea77694e3a8f> in <module>
# ----> 1 concise_cpdcrime2018_bytype
#
# NameError: name 'concise_cpdcrime2018_bytype' is not defined
