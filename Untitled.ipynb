# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import datetime
import json
import csv
from pprint import pprint

# Import API key
from api_keys import api_key
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-12c118b6c1d3> in <module>
#      11
#      12 # Import API key
# ---> 13 from api_keys import api_key
#
# ImportError: cannot import name 'api_key'

# %%
# empty lists
Cloudiness = []
Date = []
Humidity = []
Max_Temp = []
Wind_Speed = []
Weather = []

# set default values
base_url = "http://api.openweathermap.org/data/2.5/weather?"
city = "chicago"
units = "imperial"
start_date = "1388556000"
end_date = "1546236000"

#build url
weather_data = f"{base_url}q={city}&appid={api_key}&units={units}&start={start_date}&end={end_date}"
response = requests.get(weather_data).json
pprint(response)
