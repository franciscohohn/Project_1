# %%
#dependencies
import pandas as pd
import numpy as np

# files to Load
cpd_crime2018_load = "Resources/Crimes_-_2018.csv"
cpd_crime2017_load = "Resources/Crimes_-_2017.csv"
cpd_crime2016_load = "Resources/Crimes_-_2016.csv"
cpd_crime2015_load = "Resources/Crimes_-_2015.csv"
cpd_crime2014_load = "Resources/Crimes_-_2014.csv"

# read CPD crime data and store
cpdcrime2018_data = pd.read_csv(cpd_crime2018_load)
cpdcrime2017_data = pd.read_csv(cpd_crime2017_load)
cpdcrime2016_data = pd.read_csv(cpd_crime2016_load)
cpdcrime2015_data = pd.read_csv(cpd_crime2015_load)
cpdcrime2014_data = pd.read_csv(cpd_crime2014_load)

# %%
#use to check outputs
#cpdcrime2018_data.head()
#cpdcrime2017_data.head()
#cpdcrime2016_data.head()
#cpdcrime2015_data.head()
#cpdcrime2014_data.head()

# %%
#pull column data and drop NaN 
cpdcrime2018_data = cpdcrime2018_data[['Date', 'Primary Type', 'Year']]
cpdcrime2018_data = cpdcrime2018_data.dropna(how='any')

cpdcrime2017_data = cpdcrime2017_data[['Date', 'Primary Type', 'Year']]
cpdcrime2017_data = cpdcrime2017_data.dropna(how='any')

cpdcrime2016_data = cpdcrime2016_data[['Date', 'Primary Type', 'Year']]
cpdcrime2016_data = cpdcrime2016_data.dropna(how='any')

cpdcrime2015_data = cpdcrime2015_data[['Date', 'Primary Type', 'Year']]
cpdcrime2015_data = cpdcrime2015_data.dropna(how='any')

cpdcrime2014_data = cpdcrime2014_data[['Date', 'Primary Type', 'Year']]
cpdcrime2014_data = cpdcrime2014_data.dropna(how='any')

# %%
cpdcrime2018_bytype = cpdcrime2018_data.sort_values(by=["Primary Type", "Date"])
cpdcrime2017_bytype = cpdcrime2017_data.sort_values(by=["Primary Type", "Date"])
cpdcrime2016_bytype = cpdcrime2016_data.sort_values(by=["Primary Type", "Date"])
cpdcrime2015_bytype = cpdcrime2015_data.sort_values(by=["Primary Type", "Date"])
cpdcrime2014_bytype = cpdcrime2014_data.sort_values(by=["Primary Type", "Date"])

# %%
#use to check output
#cpdcrime2018_bytype
#cpdcrime2017_bytype
#cpdcrime2016_bytype
#cpdcrime2015_bytype
#cpdcrime2014_bytype

# %%
arson18 = cpdcrime2018_bytype[cpdcrime2018_bytype['Primary Type'] == "ARSON"]["Date"].reset_index()
arson17 = cpdcrime2017_bytype[cpdcrime2017_bytype['Primary Type'] == "ARSON"]["Date"].reset_index()
arson16 = cpdcrime2016_bytype[cpdcrime2016_bytype['Primary Type'] == "ARSON"]["Date"].reset_index()
arson15 = cpdcrime2015_bytype[cpdcrime2015_bytype['Primary Type'] == "ARSON"]["Date"].reset_index()
arson14 = cpdcrime2014_bytype[cpdcrime2014_bytype['Primary Type'] == "ARSON"]["Date"].reset_index()

#merge
arson_all = arson18.append([arson17, arson16, arson15, arson14])
del arson_all['index']

# %%
#use to check output
#arson18 
#arson17
#arson16
#arson15
#arson14
#arson_all

# %%
battery18 = cpdcrime2018_bytype[cpdcrime2018_bytype['Primary Type'] == "BATTERY"]["Date"].reset_index()
battery17 = cpdcrime2017_bytype[cpdcrime2017_bytype['Primary Type'] == "BATTERY"]["Date"].reset_index()
battery16 = cpdcrime2016_bytype[cpdcrime2016_bytype['Primary Type'] == "BATTERY"]["Date"].reset_index()
battery15 = cpdcrime2015_bytype[cpdcrime2015_bytype['Primary Type'] == "BATTERY"]["Date"].reset_index()
battery14 = cpdcrime2014_bytype[cpdcrime2014_bytype['Primary Type'] == "BATTERY"]["Date"].reset_index()

#merge
battery_all = battery18.append([battery17, battery16, battery15, battery14])
del battery_all['index']

# %%
#use to check output
#battery18 
#battery17
#battery16
#battery15
#battery14
#battery_all

# %%
csa18 = cpdcrime2018_bytype[cpdcrime2018_bytype['Primary Type'] == "CRIM SEXUAL ASSAULT"]["Date"].reset_index()
csa17 = cpdcrime2017_bytype[cpdcrime2017_bytype['Primary Type'] == "CRIM SEXUAL ASSAULT"]["Date"].reset_index()
csa16 = cpdcrime2016_bytype[cpdcrime2016_bytype['Primary Type'] == "CRIM SEXUAL ASSAULT"]["Date"].reset_index()
csa15 = cpdcrime2015_bytype[cpdcrime2015_bytype['Primary Type'] == "CRIM SEXUAL ASSAULT"]["Date"].reset_index()
csa14 = cpdcrime2014_bytype[cpdcrime2014_bytype['Primary Type'] == "CRIM SEXUAL ASSAULT"]["Date"].reset_index()

#merge
csa_all = csa18.append([csa17, csa16, csa15, csa14])
del csa_all['index']

# %%
#use to check output
#csa18 
#csa17
#csa16
#csa15
#csa14
#csa_all

# %%
homicide18 = cpdcrime2018_bytype[cpdcrime2018_bytype['Primary Type'] == "HOMICIDE"]["Date"].reset_index()
homicide17 = cpdcrime2017_bytype[cpdcrime2017_bytype['Primary Type'] == "HOMICIDE"]["Date"].reset_index()
homicide16 = cpdcrime2016_bytype[cpdcrime2016_bytype['Primary Type'] == "HOMICIDE"]["Date"].reset_index()
homicide15 = cpdcrime2015_bytype[cpdcrime2015_bytype['Primary Type'] == "HOMICIDE"]["Date"].reset_index()
homicide14 = cpdcrime2014_bytype[cpdcrime2014_bytype['Primary Type'] == "HOMICIDE"]["Date"].reset_index()

#merge
homicide_all = homicide18.append([homicide17, homicide16, homicide15, homicide14])
del homicide_all['index']

# %%
#use to check output
#homicide18 
#homicide17
#homicide16
#homicide15
#homicide14
#homicide_all

# %%
robbery18 = cpdcrime2018_bytype[cpdcrime2018_bytype['Primary Type'] == "ROBBERY"]["Date"].reset_index()
robbery17 = cpdcrime2017_bytype[cpdcrime2017_bytype['Primary Type'] == "ROBBERY"]["Date"].reset_index()
robbery16 = cpdcrime2016_bytype[cpdcrime2016_bytype['Primary Type'] == "ROBBERY"]["Date"].reset_index()
robbery15 = cpdcrime2015_bytype[cpdcrime2015_bytype['Primary Type'] == "ROBBERY"]["Date"].reset_index()
robbery14 = cpdcrime2014_bytype[cpdcrime2014_bytype['Primary Type'] == "ROBBERY"]["Date"].reset_index()

#merge
robbery_all = robbery18.append([robbery17, robbery16, robbery15, robbery14])
del robbery_all['index']

# %%
#use to check output
#robbery18 
#robbery17
#robbery16
#robbery15
#robbery14
#robbery_all

# %%
cpdcrime2018_bytype.set_index(["Primary Type", "Date"]).count(level="Primary Type")
# Out:
#                                     Year
# Primary Type
# ARSON                                372
# ASSAULT                            20375
# BATTERY                            49779
# BURGLARY                           11732
# CONCEALED CARRY LICENSE VIOLATION    149
# CRIM SEXUAL ASSAULT                 1626
# CRIMINAL DAMAGE                    27804
# CRIMINAL TRESPASS                   6904
# DECEPTIVE PRACTICE                 18692
# GAMBLING                             201
# HOMICIDE                             586
# HUMAN TRAFFICKING                     14
# INTERFERENCE WITH PUBLIC OFFICER    1305
# INTIMIDATION                         168
# KIDNAPPING                           169
# LIQUOR LAW VIOLATION                 266
# MOTOR VEHICLE THEFT                 9988
# NARCOTICS                          12963
# NON-CRIMINAL                          37
# NON-CRIMINAL (SUBJECT SPECIFIED)       3
# OBSCENITY                             86
# ...

# %%
concise_cpdcrime2018_bytype
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-ea77694e3a8f> in <module>
# ----> 1 concise_cpdcrime2018_bytype
#
# NameError: name 'concise_cpdcrime2018_bytype' is not defined
